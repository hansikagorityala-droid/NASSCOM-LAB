# %% [markdown]
# TASK 1

# %%
import pandas as pd

data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)
print("Number of students:", len(df))
print("\nColumn names:")

print(df.columns)
print("\nData types:")
print(df.dtypes)

print("\nFirst five records:")
print(df.head())

print("\nLast five records:")
print(df.tail())

print("\nBasic information:")
df.info()
# Out:
# Number of students: 10
#
# Column names:
# Index(['Student', 'Study_Hours', 'Attendance', 'Assignment_Score',
#        'Previous_Score', 'Final_Score'],
#       dtype='object')
#
# Data types:
# Student             object
# Study_Hours          int64
# Attendance           int64
# Assignment_Score     int64
# Previous_Score       int64
# Final_Score          int64
# dtype: object
#
# First five records:
#   Student  Study_Hours  Attendance  Assignment_Score  Previous_Score  \
# 0      S1            2          65                55              58
# 1      S2            3          70                60              62
# 2      S3            4          75                65              68
# 3      S4            5          80                72              70
# 4      S5            6          85                78              76
#
#    Final_Score
# 0           60
# 1           64
# 2           70
# 3           75
# 4           82
#
# Last five records:
# ...

# %% [markdown]
# TASK 2

# %%
import pandas as pd
data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)
print("Complete Dataset:")
print(df)

print("\nAverage Values:")
print("Average Study Hours:", df["Study_Hours"].mean())
print("Average Attendance:", df["Attendance"].mean())
print("Average Assignment Score:", df["Assignment_Score"].mean())
print("Average Previous Score:", df["Previous_Score"].mean())
print("Average Final Score:", df["Final_Score"].mean())

highest = df.loc[df["Final_Score"].idxmax()]
print("\nStudent with Highest Final Score:")
print(highest)

lowest = df.loc[df["Final_Score"].idxmin()]
print("\nStudent with Lowest Final Score:")
print(lowest)

print("\nStudents with Attendance greater than 80%:")
print(df[df["Attendance"] > 80])

print("\nStudents with Final Score greater than 80:")
print(df[df["Final_Score"] > 80])

print("\nStatistical Summary:")
print(df.describe())
# Out:
# Complete Dataset:
#   Student  Study_Hours  Attendance  Assignment_Score  Previous_Score  \
# 0      S1            2          65                55              58
# 1      S2            3          70                60              62
# 2      S3            4          75                65              68
# 3      S4            5          80                72              70
# 4      S5            6          85                78              76
# 5      S6            7          90                85              82
# 6      S7            8          92                88              86
# 7      S8            4          78                70              72
# 8      S9            6          88                80              79
# 9     S10            9          95                92              90
#
#    Final_Score
# 0           60
# 1           64
# 2           70
# 3           75
# 4           82
# 5           88
# 6           91
# 7           74
# 8           84
# 9           94
#
# ...

# %% [markdown]
# TASK 3

# %%
import numpy as np
final_scores = np.array([60, 64, 70, 75, 82, 88, 91, 74, 84, 94])

# statistical values
mean = np.mean(final_scores)
median = np.median(final_scores)
maximum = np.max(final_scores)
minimum = np.min(final_scores)
std_deviation = np.std(final_scores)

print("Final Scores:", final_scores)
print("Mean:", mean)
print("Median:", median)
print("Maximum:", maximum)
print("Minimum:", minimum)
print("Standard Deviation:", std_deviation)
# Out:
# Final Scores: [60 64 70 75 82 88 91 74 84 94]
# Mean: 78.2
# Median: 78.5
# Maximum: 94
# Minimum: 60
# Standard Deviation: 10.88852607105296

# %% [markdown]
# TASK 4

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}

df = pd.DataFrame(data)

#study hours vs final score
plt.scatter(df["Study_Hours"], df["Final_Score"])
plt.xlabel("Study Hours")
plt.ylabel("Final Score")
plt.title("Study Hours vs Final Score")
plt.show()

#attendance vs final score
plt.scatter(df["Attendance"], df["Final_Score"])
plt.xlabel("Attendance (%)")
plt.ylabel("Final Score")
plt.title("Attendance vs Final Score")
plt.show()

#Distribution of final scores
plt.hist(df["Final_Score"], bins=5,color="teal",edgecolor="black")
plt.xlabel("Final Score")
plt.ylabel("Number of Students")
plt.title("Distribution of Final Scores")
plt.show()

#student-wise final scores
plt.bar(df["Student"], df["Final_Score"])
plt.xlabel("Student")
plt.ylabel("Final Score")
plt.title("Student-wise Final Scores")
plt.show()

# %% [markdown]
# TASK 5

# %%
import numpy as np

X = df[["Study_Hours", "Attendance", "Assignment_Score"]].values

print("Matrix X:")

print(X)
# Out:
# Matrix X:
# [[ 2 65 55]
#  [ 3 70 60]
#  [ 4 75 65]
#  [ 5 80 72]
#  [ 6 85 78]
#  [ 7 90 85]
#  [ 8 92 88]
#  [ 4 78 70]
#  [ 6 88 80]
#  [ 9 95 92]]

# %%
print("Shape:", X.shape)
# Out:
# Shape: (10, 3)

# %%
print("Transpose X^T:")
print(X.T)
# Out:
# Transpose X^T:
# [[ 2  3  4  5  6  7  8  4  6  9]
#  [65 70 75 80 85 90 92 78 88 95]
#  [55 60 65 72 78 85 88 70 80 92]]

# %%
XT_X = X.T @ X

print("X transpose X:")
print(XT_X)
# Out:
# X transpose X:
# [[  336  4611  4265]
#  [ 4611 67792 62026]
#  [ 4265 62026 56851]]

# %%
study_hours = df["Study_Hours"].values
final_scores = df["Final_Score"].values

dot_product = np.dot(study_hours, final_scores)

print("Dot product:", dot_product)
# Out:
# Dot product: 4449

# %% [markdown]
# TASK 6

# %% [markdown]
# 20. Differentiate each term:
#
# $$ F(x)=40+5x-0.2x^2 $$
#
# Using the basic differentiation rules:
#
# $$ \frac{d}{dx}(40)=0 $$ $$ \frac{d}{dx}(5x)=5 $$ $$ \frac{d}{dx}(-0.2x^2)=-0.4x $$
#
# Therefore,
#
# dx
# dF
# 	​
#
# =5−0.4x
# 	​

# %% [markdown]
# 21.
# $$ F(x)=40+5x-0.2x^2 $$
#
# Taking the derivative:
#
# $$ F'(x)=0+5-0.2(2x) $$ $$ F'(x)=5-0.4x $$
#
# Hence,
#
# $$ {F'(x)=5-0.4x} $$

# %% [markdown]
# 22.Set the derivative equal to zero:
#
# $$ 5-0.4x=0 $$ $$ 0.4x=5 $$ $$ x=\frac{5}{0.4} $$ $$ {x=12.5} $$
#
# Therefore, the stationary point occurs at 12.5 study hours.
#
# We can also calculate the predicted score at this point:
#
# $$ F(12.5)=40+5(12.5)-0.2(12.5)^2 $$ $$ =40+62.5-31.25 $$ $$ {F(12.5)=71.25} $$

# %% [markdown]
# 23. Interpretation
#
# The derivative tells us how the predicted final score changes when study hours increase.
#
# If \(x<12.5\), then \(F'(x)>0\), so the predicted score increases as study hours increase.
# If \(x=12.5\), then \(F'(x)=0\), so the model reaches its maximum predicted score.
# If \(x>12.5\), then \(F'(x)<0\), so the model predicts that the score decreases as study hours continue to increase.
#
# Therefore, according to this given mathematical model:
#
# $$ {\text{Maximum predicted score occurs at }x=12.5\text{ study hours}} $$
#
# with a predicted score of 71.25.

# %% [markdown]
# PYTHON VERIFICATION

# %%
def F(x):
    return 40 + 5*x - 0.2*x**2

def dF(x):
    return 5 - 0.4*x

for x in range(1, 11):
    print(x, F(x), dF(x))
# Out:
# 1 44.8 4.6
# 2 49.2 4.2
# 3 53.2 3.8
# 4 56.8 3.4
# 5 60.0 3.0
# 6 62.8 2.5999999999999996
# 7 65.2 2.1999999999999997
# 8 67.2 1.7999999999999998
# 9 68.8 1.4
# 10 70.0 1.0

# %% [markdown]
# Calculus: Integration

# %% [markdown]
# 24.
#
# Substitute \(L(x)\):
#
# $$ \int_0^5(5x-0.2x^2)\,dx $$
#
# Integrate each term:
#
# $$ \int 5x\,dx=\frac{5x^2}{2}=2.5x^2 $$
#
# and
#
# $$ \int -0.2x^2\,dx=-\frac{0.2x^3}{3} $$
#
# Therefore:
#
# $$ \int_0^5L(x)\,dx = \left[2.5x^2-\frac{0.2x^3}{3}\right]_0^5 $$
#
# At \(x=5\):
#
# $$ 2.5(5)^2-\frac{0.2(5)^3}{3} $$ $$ =62.5-\frac{25}{3} $$ $$ =62.5-8.3333 $$ $$ {54.1667} $$
#
# So the value of the integral is approximately 54.17.

# %% [markdown]
# 25. Numerical approximation using Python

# %%
import numpy as np

def L(x):
    return 5*x - 0.2*x**2

# using trapezoidal rule
x = np.linspace(0, 5, 1000)
area = np.trapezoid(L(x), x)

print("Numerical integral:", area)
# Out:
# Numerical integral: 54.166662491654144

# %% [markdown]
# 26. Meaning of the area under the curve
#
# The area under \(L(x)\) from 0 to 5 represents the total accumulated learning benefit over study hours 0 to 5, according to the given mathematical model.
#
# Therefore:
#
# $$ {\text{Total learning benefit} \approx 54.17} $$

# %% [markdown]
# **Correlation Analysis**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# correlation matrix
correlation = df.corr(numeric_only=True)

print(correlation)

# correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#                   Study_Hours  Attendance  Assignment_Score  Previous_Score  \
# Study_Hours          1.000000    0.980663          0.989005        0.983564
# Attendance           0.980663    1.000000          0.996235        0.988384
# Assignment_Score     0.989005    0.996235          1.000000        0.992736
# Previous_Score       0.983564    0.988384          0.992736        1.000000
# Final_Score          0.985898    0.997256          0.998870        0.993567
#
#                   Final_Score
# Study_Hours          0.985898
# Attendance           0.997256
# Assignment_Score     0.998870
# Previous_Score       0.993567
# Final_Score          1.000000

# %% [markdown]
# The calculated correlations are:
#
# Study Hours → 0.9859
# Attendance → 0.9973
# Assignment Score → 0.9989
# Previous Score → 0.9936

# %% [markdown]
# Part I – Mini Prediction Model Using Linear Algebra

# %%
import numpy as np

# input variables
X = df[["Study_Hours", "Attendance", "Assignment_Score"]].values
# target variable
Y = df["Final_Score"].values

X = np.column_stack((np.ones(len(X)), X))

# (X^T X)^-1 X^T Y
beta = np.linalg.inv(X.T @ X) @ X.T @ Y

print("Coefficients:")
print(beta)
# Out:
# Coefficients:
# [ 0.27329803 -0.181712    0.30662738  0.72249433]

# %% [markdown]
# **interpretation of the coefficients**

# %% [markdown]
# intercept: 0.2733
#
# The intercept is the model's predicted Final Score when all three input variables are zero.
#
# Study Hours: -0.1817
#
# Holding attendance and assignment score constant, the fitted model has a coefficient of approximately -0.182 for study hours.
#
# Attendance: 0.3066
#
# Holding the other variables constant, a one-unit increase in attendance is associated with approximately 0.307 points higher predicted Final Score.
#
# Assignment Score: 0.7225
#
# Holding the other variables constant, a one-point increase in Assignment Score is associated with approximately 0.722 points higher predicted Final Score.
#
# Important observation
#
# The negative Study Hours coefficient does not contradict the earlier positive correlation (0.9859).In the linear model, the Study Hours coefficient represents its relationship after simultaneously accounting for Attendance and Assignment Score.

# %% [markdown]
# **13.  – Final Interpretation
#
# 27. What is the average final score?
# 28. How much variation is present in the final scores?
# 29. Which student obtained the highest final score?
# 30. What relationship do you observe between study hours and final score?
# 31. What relationship do you observe between attendance and final score?
# 32. Which variable has the strongest correlation with final score?
# 33. Why is matrix representation useful for multiple input variables?
# 34. What does the derivative represent in the study-hours model?
# 35. What does the area under the learning-benefit curve represent?
# 36. What are the main conclusions from the complete analysis?**

# %% [markdown]
# **27**. What is the average final score?
#
# The average Final Score is:
#
# $$ \frac{60+64+70+75+82+88+91+74+84+94}{10} ={79.2} $$
#
# So, the average final score is 79.2 marks.
#
# **28.** How much variation is present in the final scores?
#
# The NumPy standard deviation is approximately:
#
# $$ {10.85} $$
#
# This means the Final Scores typically vary by about 10.85 marks from the mean score of 79.2.
#
# The scores range from 60 to 94, giving a range of:
#
# $$ 94-60={34} $$
#
# So, there is a noticeable amount of variation among students' final scores.
#
# **29.** Which student obtained the highest final score?
#
# S10 obtained the highest Final Score:
#
# $$ {94} $$
#
# The lowest score was S1 with 60.
#
# **30.** What relationship do you observe between study hours and final score?
#
# There is a strong positive relationship between Study Hours and Final Score.
#
# The correlation is approximately:
#
# $$ {r=0.9859} $$
#
# In this dataset, students who study more hours generally have higher final scores.
#
# Study hours vs final score
#
# The student observations show a strong positive association between study hours and final score.

# %% [markdown]
# **31.**There is also a very strong positive relationship between Attendance and Final Score.
#
# The correlation is approximately:
#
# $$ {r=0.9973} $$
#
# Students with higher attendance generally have higher final scores in this dataset.
#
# Attendance vs final score
#
# The student observations show a very strong positive association between attendance and final score.

# %% [markdown]
# **32.** Which variable has the strongest correlation with Final Score?
#
# The calculated correlations are:
#
# Variable	Correlation with Final Score
# Study Hours	0.9859
# Attendance	0.9973
# Assignment Score	0.9989
# Previous Score	0.9936
#
# Therefore, Assignment Score has the strongest correlation with Final Score, with:
#
# $$ {r=0.9989} $$
#
# This indicates an extremely strong positive linear association in this dataset. Correlation alone does not prove that one variable causes the other.

# %% [markdown]
# **33.**
#
# Matrix representation allows several input variables to be handled together in a compact mathematical form.
#
# For example:
#
# $$ X= \begin{bmatrix} \text{Study Hours} & \text{Attendance} & \text{Assignment Score} \end{bmatrix} $$
#
# With 10 students, \(X\) becomes a 10 × 3 matrix.
#
# This is useful because:
#
# Large datasets can be represented efficiently.
# Multiple variables can be processed simultaneously.
# Matrix operations simplify calculations.
# It provides the foundation for linear regression and prediction models.
# It is easier to extend the model when more input variables are added.
#
# **34.**
# The model is:
#
# $$ F(x)=40+5x-0.2x^2 $$
#
# Its derivative is:
#
# $$ F'(x)=5-0.4x $$
#
# The derivative represents the rate of change of the predicted Final Score with respect to study hours.
#
# At \(x=12.5\):
#
# $$ F'(12.5)=0 $$
#
# According to this mathematical model, 12.5 study hours is the stationary point, where the predicted score reaches its maximum.
#
# **35.**
# The learning-benefit function is:
#
# $$ L(x)=5x-0.2x^2 $$
#
# The area from 0 to 5 hours is:
#
# $$ \int_0^5L(x)\,dx={54.17} $$
#
# This represents the total accumulated learning benefit over the study-hour interval from 0 to 5, according to the given model.
#
# **36.** Main Conclusions from the Complete Analysis
# The average Final Score is 79.2.
# The standard deviation is approximately 10.85, showing noticeable variation in student performance.
# S10 achieved the highest Final Score of 94.
# Study Hours have a strong positive association with Final Score (\(r=0.9859\)).
# Attendance has a very strong positive association with Final Score (\(r=0.9973\)).
